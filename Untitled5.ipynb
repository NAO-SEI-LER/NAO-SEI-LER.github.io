# %% [markdown]
# <a href="https://colab.research.google.com/github/NAO-SEI-LER/NAO-SEI-LER.github.io/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/yolov5/
# !python val.py --weights /content/drive/MyDrive/YOLOv5_Weights/yolov5s_results2/weights/best.pt --data /content/Larva-Aedes-Aegypti-3/data.yaml --task test --project /content/drive/MyDrive/YOLOv5_Weights/comparacao --name modelo_novo_results
# !python val.py --weights /content/drive/MyDrive/YOLOv5_Weights/exp2/weights/best.pt --data /content/Larva-Aedes-Aegypti-3/data.yaml --task test --project /content/drive/MyDrive/YOLOv5_Weights/comparacao --name modelo_antigo_results
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 16.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# val: data=/content/Larva-Aedes-Aegypti-3/data.yaml, weights=['/content/drive/MyDrive/YOLOv5_Weights/yolov5s_results2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=/content/drive/MyDrive/YOLOv5_Weights/comparacao, name=modelo_novo_results, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CPU
#
# Fusing layers...
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="11mBf88I6yvJO7Qfj9cd")
project = rf.workspace("meu-tcc").project("larva-aedes-aegypti")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Larva-Aedes-Aegypti-4 in yolov5pytorch:: 100%|██████████| 2896/2896 [00:00<00:00, 8356.95it/s]

# %%
# clone YOLOv5 repository
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17022, done.
# remote: Total 17022 (delta 0), reused 0 (delta 0), pack-reused 17022 (from 1)
# Receiving objects: 100% (17022/17022), 15.62 MiB | 27.20 MiB/s, done.
# Resolving deltas: 100% (11694/11694), done.

# %%
# !pip install -r requirements.txt
# !pip uninstall wandb -qy  # deprecated dependency
import torch

from IPython.display import Image, clear_output  # to display images

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Setup complete. Using torch 2.5.0+cu121 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', major=8, minor=0, total_memory=40513MB, multi_processor_count=108, uuid=7c3e8a3e-abe3-36e6-a945-866695465e27, L2_cache_size=40MB)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="11mBf88I6yvJO7Qfj9cd")
project = rf.workspace("meu-tcc").project("larva-aedes-aegypti")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Larva-Aedes-Aegypti-3 in yolov5pytorch:: 100%|██████████| 28308/28308 [00:08<00:00, 3206.64it/s]

# %%
# %%time
# %cd /content/yolov5/
# !python train.py \
  --img  640 \
  --batch 64 \
  --epochs 300 \
  --data {dataset.location}/data.yaml \
  --weights /content/drive/MyDrive/YOLOv5_Weights/exp2/weights/best.pt \
  --name yolov5s_results \
  --cache \
  --patience 10 \
  --project /content/drive/MyDrive/YOLOv5_Weights
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 17.2 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 2024-10-29 01:59:24.192273: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 01:59:24.211649: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %%time
# %cd /content/yolov5/
# !python train.py \
  --img  640 \
  --batch 64 \
  --epochs 300 \
  --data {dataset.location}/data.yaml \
  --weights /content/drive/MyDrive/YOLOv5_Weights/exp2/weights/best.pt \
  --name yolov5s_results \
  --cache \
  --patience 20 \
  --project /content/drive/MyDrive/YOLOv5_Weights
# Out:
# /content/yolov5
# 2024-10-29 02:02:27.271670: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 02:02:27.292501: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 02:02:27.298862: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# prompt: codigo para descompactar esse arquivo /content/slasla.rar

# !unrar x /content/slasla.rar /content/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/slasla.rar
#
# Creating    /content/slasla                                           OK
#   OK
#   OK
#   OK
# Creating    /content/slasla/test                                      OK
# Creating    /content/slasla/test/images                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/slasla/test/labels                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# %cd /content/yolov5/
# !python val.py --weights /content/drive/MyDrive/YOLOv5_Weights/modelo2/weights/best.pt --data /content/slasla/data.yaml --task test --project /content/drive/MyDrive/YOLOv5_Weights/comparacao --name modelo_novo_results
# !python val.py --weights /content/drive/MyDrive/YOLOv5_Weights/modelo1/weights/best.pt --data /content/slasla/data.yaml --task test --project /content/drive/MyDrive/YOLOv5_Weights/comparacao --name modelo_antigo_results
# Out:
# /content/yolov5
# val: data=/content/slasla/data.yaml, weights=['/content/drive/MyDrive/YOLOv5_Weights/modelo2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=/content/drive/MyDrive/YOLOv5_Weights/comparacao, name=modelo_novo_results, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/slasla/test/labels... 62 images, 0 backgrounds, 0 corrupt: 100% 62/62 [00:00<00:00, 3552.31it/s]
# test: New cache created: /content/slasla/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.36s/it]
# ...
